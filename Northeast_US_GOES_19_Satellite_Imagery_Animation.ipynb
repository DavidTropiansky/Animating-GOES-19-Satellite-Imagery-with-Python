# %%
# USE THIS FOR 600x600 IMAGES #
import os
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from io import BytesIO
from PIL import Image
import imageio.v3 as iio
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime

BASE_URL = "https://cdn.star.nesdis.noaa.gov/GOES19/ABI/SECTOR/ne/GEOCOLOR/"
MAX_IMAGES = 432 # About 3 days of imagery with the filtered times
START_TIME = 1100   # For full 24 hour day, start time: 0000, end time: 2359
END_TIME = 2305
FPS = 30
THREADS = 10

def list_image_urls():
    resp = requests.get(BASE_URL)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    img_urls = []
    regex = re.compile(r".*600x600\.jpg$")
    for a in soup.find_all('a', href=True):
        href = a['href']
        if not regex.match(href):
            continue

        m = re.search(r"(\d{4})_GOES19", href)
        if not m:
            continue
        time_str = m.group(1)

        try:
            time_int = int(time_str)
        except ValueError:
            continue

        if START_TIME <= time_int <= END_TIME:
            img_urls.append(urljoin(BASE_URL, href))

    return sorted(img_urls)[-MAX_IMAGES:]

def fetch_image(index, url, total):
    try:
        print(f"Fetching image {index+1}/{total}: {os.path.basename(url)}")
        r = requests.get(url, stream=True, timeout=10)
        r.raise_for_status()
        img = Image.open(BytesIO(r.content)).convert("RGB")
        return (index, img)
    except Exception as e:
        print(f"Failed to fetch {url}: {e}")
        return (index, None)

def create_mp4_from_images(images, output_path, fps=FPS):
    images = [img for img in images if img]
    if not images:
        print("No images to animate.")
        return
    print(f"Creating MP4 with {len(images)} frames at {fps} FPS...")
    iio.imwrite(output_path, images, fps=fps)
    print(f"Saved animation to {output_path}")

def main():
    urls = list_image_urls()
    print(f"Found {len(urls)} recent 600x600 images between {START_TIME} and {END_TIME}")

    total = len(urls)
    images = [None] * total

    with ThreadPoolExecutor(max_workers=THREADS) as executor:
        futures = [executor.submit(fetch_image, i, url, total) for i, url in enumerate(urls)]
        for future in as_completed(futures):
            index, img = future.result()
            images[index] = img

    timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M")
    output_path = f"animation_{timestamp}.mp4"
    create_mp4_from_images(images, output_path)

if __name__ == "__main__":
    main()
# Out:
# Found 432 recent 600x600 images between 1100 and 2305
# Fetching image 1/432: 20251601116_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 2/432: 20251601121_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 3/432: 20251601126_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 4/432: 20251601131_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 5/432: 20251601136_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 6/432: 20251601141_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 7/432: 20251601146_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 8/432: 20251601151_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 9/432: 20251601156_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 10/432: 20251601201_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 11/432: 20251601206_GOES19-ABI-ne-GEOCOLOR-600x600.jpgFetching image 12/432: 20251601211_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
#
# Fetching image 13/432: 20251601216_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 14/432: 20251601221_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 15/432: 20251601226_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 16/432: 20251601231_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 17/432: 20251601236_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 18/432: 20251601241_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 19/432: 20251601246_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 20/432: 20251601251_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 21/432: 20251601256_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 22/432: 20251601301_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 23/432: 20251601306_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 24/432: 20251601311_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 25/432: 20251601316_GOES19-ABI-ne-GEOCOLOR-600x600.jpgFetching image 26/432: 20251601321_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
#
# Fetching image 27/432: 20251601326_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 28/432: 20251601331_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 29/432: 20251601336_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 30/432: 20251601341_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 31/432: 20251601346_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 32/432: 20251601351_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 33/432: 20251601356_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 34/432: 20251601401_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 35/432: 20251601406_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 36/432: 20251601411_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 37/432: 20251601416_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 38/432: 20251601421_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 39/432: 20251601426_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 40/432: 20251601431_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 41/432: 20251601436_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 42/432: 20251601441_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 43/432: 20251601446_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 44/432: 20251601451_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 45/432: 20251601456_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 46/432: 20251601501_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 47/432: 20251601506_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 48/432: 20251601511_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 49/432: 20251601516_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 50/432: 20251601521_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 51/432: 20251601526_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 52/432: 20251601531_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 53/432: 20251601536_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 54/432: 20251601541_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 55/432: 20251601546_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 56/432: 20251601551_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 57/432: 20251601556_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 58/432: 20251601601_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 59/432: 20251601606_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 60/432: 20251601611_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 61/432: 20251601616_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 62/432: 20251601621_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 63/432: 20251601626_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 64/432: 20251601631_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 65/432: 20251601636_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 66/432: 20251601641_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 67/432: 20251601646_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 68/432: 20251601651_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 69/432: 20251601656_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 70/432: 20251601701_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 71/432: 20251601706_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 72/432: 20251601711_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 73/432: 20251601716_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 74/432: 20251601721_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 75/432: 20251601726_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 76/432: 20251601731_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 77/432: 20251601736_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 78/432: 20251601741_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 79/432: 20251601746_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 80/432: 20251601751_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 81/432: 20251601756_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 82/432: 20251601801_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 83/432: 20251601806_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 84/432: 20251601811_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 85/432: 20251601816_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 86/432: 20251601821_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 87/432: 20251601826_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 88/432: 20251601831_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 89/432: 20251601836_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 90/432: 20251601841_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 91/432: 20251601846_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 92/432: 20251601851_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 93/432: 20251601856_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 94/432: 20251601901_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 95/432: 20251601906_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 96/432: 20251601911_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 97/432: 20251601916_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 98/432: 20251601921_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 99/432: 20251601926_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 100/432: 20251601931_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 101/432: 20251601936_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 102/432: 20251601941_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 103/432: 20251601946_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 104/432: 20251601951_GOES19-ABI-ne-GEOCOLOR-600x600.jpgFetching image 105/432: 20251601956_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 106/432: 20251602001_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 107/432: 20251602006_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 108/432: 20251602011_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 109/432: 20251602016_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 110/432: 20251602021_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 111/432: 20251602026_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
#
# Fetching image 112/432: 20251602031_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 113/432: 20251602036_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 114/432: 20251602041_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 115/432: 20251602046_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 116/432: 20251602051_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 117/432: 20251602056_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 118/432: 20251602101_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 119/432: 20251602106_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 120/432: 20251602111_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 121/432: 20251602116_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 122/432: 20251602121_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 123/432: 20251602126_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 124/432: 20251602131_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 125/432: 20251602136_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 126/432: 20251602141_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 127/432: 20251602146_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 128/432: 20251602151_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 129/432: 20251602156_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 130/432: 20251602201_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 131/432: 20251602206_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 132/432: 20251602211_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 133/432: 20251602216_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 134/432: 20251602221_GOES19-ABI-ne-GEOCOLOR-600x600.jpgFetching image 135/432: 20251602226_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 136/432: 20251602231_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 137/432: 20251602236_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 138/432: 20251602241_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 139/432: 20251602246_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 140/432: 20251602251_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
#
# Fetching image 141/432: 20251602256_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 142/432: 20251602301_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 143/432: 20251611101_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 144/432: 20251611106_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 145/432: 20251611111_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 146/432: 20251611116_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 147/432: 20251611121_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 148/432: 20251611126_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 149/432: 20251611131_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 150/432: 20251611136_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 151/432: 20251611141_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 152/432: 20251611146_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 153/432: 20251611151_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 154/432: 20251611156_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 155/432: 20251611201_GOES19-ABI-ne-GEOCOLOR-600x600.jpgFetching image 156/432: 20251611206_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 157/432: 20251611211_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
#
# Fetching image 158/432: 20251611216_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 159/432: 20251611221_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 160/432: 20251611226_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 161/432: 20251611231_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 162/432: 20251611236_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 163/432: 20251611241_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 164/432: 20251611246_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 165/432: 20251611251_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 166/432: 20251611256_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 167/432: 20251611301_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 168/432: 20251611306_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 169/432: 20251611311_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 170/432: 20251611316_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 171/432: 20251611321_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 172/432: 20251611326_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 173/432: 20251611331_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 174/432: 20251611336_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 175/432: 20251611341_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 176/432: 20251611346_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 177/432: 20251611351_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 178/432: 20251611356_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 179/432: 20251611401_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 180/432: 20251611406_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 181/432: 20251611411_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 182/432: 20251611416_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 183/432: 20251611421_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 184/432: 20251611426_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 185/432: 20251611431_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 186/432: 20251611436_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 187/432: 20251611441_GOES19-ABI-ne-GEOCOLOR-600x600.jpgFetching image 188/432: 20251611446_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 189/432: 20251611451_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 190/432: 20251611456_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 191/432: 20251611501_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 192/432: 20251611506_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
#
# Fetching image 193/432: 20251611511_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 194/432: 20251611516_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 195/432: 20251611521_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 196/432: 20251611526_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 197/432: 20251611531_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 198/432: 20251611536_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 199/432: 20251611541_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 200/432: 20251611546_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 201/432: 20251611551_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 202/432: 20251611556_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 203/432: 20251611601_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 204/432: 20251611606_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 205/432: 20251611611_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 206/432: 20251611616_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 207/432: 20251611621_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 208/432: 20251611626_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 209/432: 20251611631_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 210/432: 20251611636_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 211/432: 20251611641_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 212/432: 20251611646_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 213/432: 20251611651_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 214/432: 20251611656_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 215/432: 20251611701_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 216/432: 20251611706_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 217/432: 20251611711_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 218/432: 20251611716_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 219/432: 20251611721_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 220/432: 20251611726_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 221/432: 20251611731_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 222/432: 20251611736_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 223/432: 20251611741_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 224/432: 20251611746_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 225/432: 20251611751_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 226/432: 20251611756_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 227/432: 20251611801_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 228/432: 20251611806_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 229/432: 20251611811_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 230/432: 20251611816_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 231/432: 20251611821_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 232/432: 20251611826_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 233/432: 20251611831_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 234/432: 20251611836_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 235/432: 20251611841_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 236/432: 20251611846_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 237/432: 20251611851_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 238/432: 20251611856_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 239/432: 20251611901_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 240/432: 20251611906_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 241/432: 20251611911_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 242/432: 20251611916_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 243/432: 20251611921_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 244/432: 20251611926_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 245/432: 20251611931_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 246/432: 20251611936_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 247/432: 20251611941_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 248/432: 20251611946_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 249/432: 20251611951_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 250/432: 20251611956_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 251/432: 20251612001_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 252/432: 20251612006_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 253/432: 20251612011_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 254/432: 20251612016_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 255/432: 20251612021_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 256/432: 20251612026_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 257/432: 20251612031_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 258/432: 20251612036_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 259/432: 20251612041_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 260/432: 20251612046_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 261/432: 20251612051_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 262/432: 20251612056_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 263/432: 20251612101_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 264/432: 20251612106_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 265/432: 20251612111_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 266/432: 20251612116_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 267/432: 20251612121_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 268/432: 20251612126_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 269/432: 20251612131_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 270/432: 20251612136_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 271/432: 20251612141_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 272/432: 20251612146_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 273/432: 20251612151_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 274/432: 20251612156_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 275/432: 20251612201_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 276/432: 20251612206_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 277/432: 20251612211_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 278/432: 20251612216_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 279/432: 20251612221_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 280/432: 20251612226_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 281/432: 20251612231_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 282/432: 20251612236_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 283/432: 20251612241_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 284/432: 20251612246_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 285/432: 20251612251_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 286/432: 20251612256_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 287/432: 20251612301_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 288/432: 20251621101_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 289/432: 20251621106_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 290/432: 20251621111_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 291/432: 20251621116_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 292/432: 20251621121_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 293/432: 20251621126_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 294/432: 20251621131_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 295/432: 20251621136_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 296/432: 20251621141_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 297/432: 20251621146_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 298/432: 20251621151_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 299/432: 20251621156_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 300/432: 20251621201_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 301/432: 20251621206_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 302/432: 20251621211_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 303/432: 20251621216_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 304/432: 20251621221_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 305/432: 20251621226_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 306/432: 20251621231_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 307/432: 20251621236_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 308/432: 20251621241_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 309/432: 20251621246_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 310/432: 20251621251_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 311/432: 20251621256_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 312/432: 20251621301_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 313/432: 20251621306_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 314/432: 20251621311_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 315/432: 20251621316_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 316/432: 20251621321_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 317/432: 20251621326_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 318/432: 20251621331_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 319/432: 20251621336_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 320/432: 20251621341_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 321/432: 20251621346_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 322/432: 20251621351_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 323/432: 20251621356_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 324/432: 20251621401_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 325/432: 20251621406_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 326/432: 20251621411_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 327/432: 20251621416_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 328/432: 20251621421_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 329/432: 20251621426_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 330/432: 20251621431_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 331/432: 20251621436_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 332/432: 20251621441_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 333/432: 20251621446_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 334/432: 20251621451_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 335/432: 20251621456_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 336/432: 20251621501_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 337/432: 20251621506_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 338/432: 20251621511_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 339/432: 20251621516_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 340/432: 20251621521_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 341/432: 20251621526_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 342/432: 20251621531_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 343/432: 20251621536_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 344/432: 20251621541_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 345/432: 20251621546_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 346/432: 20251621551_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 347/432: 20251621556_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 348/432: 20251621601_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 349/432: 20251621606_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 350/432: 20251621611_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 351/432: 20251621616_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 352/432: 20251621621_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 353/432: 20251621626_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 354/432: 20251621631_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 355/432: 20251621636_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 356/432: 20251621641_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 357/432: 20251621646_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 358/432: 20251621651_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 359/432: 20251621656_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 360/432: 20251621701_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 361/432: 20251621706_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 362/432: 20251621711_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 363/432: 20251621716_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 364/432: 20251621721_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 365/432: 20251621726_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 366/432: 20251621731_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 367/432: 20251621736_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 368/432: 20251621741_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 369/432: 20251621746_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 370/432: 20251621751_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 371/432: 20251621756_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 372/432: 20251621801_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 373/432: 20251621806_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 374/432: 20251621811_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 375/432: 20251621816_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 376/432: 20251621821_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 377/432: 20251621826_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 378/432: 20251621831_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 379/432: 20251621836_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 380/432: 20251621841_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 381/432: 20251621846_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 382/432: 20251621851_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 383/432: 20251621856_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 384/432: 20251621901_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 385/432: 20251621906_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 386/432: 20251621911_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 387/432: 20251621916_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 388/432: 20251621921_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 389/432: 20251621926_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 390/432: 20251621931_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 391/432: 20251621936_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 392/432: 20251621941_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 393/432: 20251621946_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 394/432: 20251621951_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 395/432: 20251621956_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 396/432: 20251622001_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 397/432: 20251622006_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 398/432: 20251622011_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 399/432: 20251622016_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 400/432: 20251622021_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 401/432: 20251622026_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 402/432: 20251622031_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 403/432: 20251622036_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 404/432: 20251622041_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 405/432: 20251622046_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 406/432: 20251622051_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 407/432: 20251622056_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 408/432: 20251622101_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 409/432: 20251622106_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 410/432: 20251622111_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 411/432: 20251622116_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 412/432: 20251622121_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 413/432: 20251622126_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 414/432: 20251622131_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 415/432: 20251622136_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 416/432: 20251622141_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 417/432: 20251622146_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 418/432: 20251622151_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 419/432: 20251622156_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 420/432: 20251622201_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 421/432: 20251622206_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 422/432: 20251622211_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 423/432: 20251622216_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 424/432: 20251622221_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 425/432: 20251622226_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 426/432: 20251622231_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 427/432: 20251622236_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 428/432: 20251622241_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 429/432: 20251622246_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 430/432: 20251622251_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 431/432: 20251622256_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Fetching image 432/432: 20251622301_GOES19-ABI-ne-GEOCOLOR-600x600.jpg
# Creating MP4 with 432 frames at 30 FPS...
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 600) to (608, 608) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Saved animation to animation_2025-06-12_02-11.mp4

# %%
# USE FOR 1200X1200 IMAGES #
import os
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from io import BytesIO
from PIL import Image
import imageio.v3 as iio
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime

BASE_URL = "https://cdn.star.nesdis.noaa.gov/GOES19/ABI/SECTOR/ne/GEOCOLOR/"
MAX_IMAGES = 200
START_TIME = 1100   # For full 24 hour day, start time: 0000, end time: 2359
END_TIME = 2359
FPS = 30
THREADS = 10

def list_image_urls():
    resp = requests.get(BASE_URL)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    img_urls = []
    regex = re.compile(r".*1200x1200\.jpg$")
    for a in soup.find_all('a', href=True):
        href = a['href']
        if not regex.match(href):
            continue

        m = re.search(r"(\d{4})_GOES19", href)
        if not m:
            continue
        time_str = m.group(1)

        try:
            time_int = int(time_str)
        except ValueError:
            continue

        if START_TIME <= time_int <= END_TIME:
            img_urls.append(urljoin(BASE_URL, href))

    return sorted(img_urls)[-MAX_IMAGES:]

def fetch_image(index, url, total):
    try:
        print(f"Fetching image {index+1}/{total}: {os.path.basename(url)}")
        r = requests.get(url, stream=True, timeout=10)
        r.raise_for_status()
        img = Image.open(BytesIO(r.content)).convert("RGB")
        return (index, img)
    except Exception as e:
        print(f"Failed to fetch {url}: {e}")
        return (index, None)

def create_mp4_from_images(images, output_path, fps=FPS):
    images = [img for img in images if img]
    if not images:
        print("No images to animate.")
        return
    print(f"Creating MP4 with {len(images)} frames at {fps} FPS...")
    iio.imwrite(output_path, images, fps=fps)
    print(f"Saved animation to {output_path}")

def main():
    urls = list_image_urls()
    print(f"Found {len(urls)} recent 1200x1200 images between {START_TIME} and {END_TIME}")

    total = len(urls)
    images = [None] * total

    with ThreadPoolExecutor(max_workers=THREADS) as executor:
        futures = [executor.submit(fetch_image, i, url, total) for i, url in enumerate(urls)]
        for future in as_completed(futures):
            index, img = future.result()
            images[index] = img

    timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M")
    output_path = f"animation_{timestamp}.mp4"
    create_mp4_from_images(images, output_path)

if __name__ == "__main__":
    main()
